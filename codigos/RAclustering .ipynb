# %%
import networkx as nx
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from networkx.algorithms import bipartite

# %%
AT08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2008.gml')
BE08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2008.gml')
BG08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2008.gml')
CY08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2008.gml')
CZ08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2008.gml')
DE08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2008.gml')
DK08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2008.gml')
EE08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2008.gml')
ES08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2008.gml')
FI08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2008.gml')
FR08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2008.gml')
GR08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2008.gml')
HU08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2008.gml')
IE08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2008.gml')
IT08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2008.gml')
LT08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2008.gml')
LV08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2008.gml')
NL08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2008.gml')
NO08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2008.gml')
PL08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2008.gml')
PT08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2008.gml')
RO08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2008.gml')
SE08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2008.gml')
SI08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2008.gml')
SK08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2008.gml')
UK08=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2008.gml')

# %%
Clusters2008 = np.array((round(bipartite.robins_alexander_clustering(AT08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(BE08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(BG08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(CY08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(CZ08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(DE08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(DK08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(EE08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(ES08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(FI08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(FR08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(GR08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(HU08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(IE08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(IT08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(LT08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(LV08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(NL08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(NO08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(PL08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(PT08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(RO08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(SE08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(SI08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(SK08), 3)))
Clusters2008 = np.append(Clusters2008,(round(bipartite.robins_alexander_clustering(UK08), 3)))

# %%
df_Clusters2008=pd.DataFrame(Clusters2008, columns=['Y2008'])

# %%
df_Clusters2008
# Out:
#     Y2008
# 0   0.026
# 1   0.021
# 2   0.239
# 3   0.007
# 4   0.035
# 5   0.011
# 6   0.034
# 7   0.085
# 8   0.117
# 9   0.055
# 10  0.099
# 11  0.126
# 12  0.089
# 13  0.025
# 14  0.079
# 15  0.288
# 16  0.177
# 17  0.009
# 18  0.032
# 19  0.245
# 20  0.108
# 21  0.315
# 22  0.046
# 23  0.298
# 24  0.145
# 25  0.032

# %%
df_Clusters2008.to_excel('Cluster2008.xlsx')

# %%
AT09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2009.gml')
BE09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2009.gml')
BG09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2009.gml')
CY09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2009.gml')
CZ09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2009.gml')
DE09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2009.gml')
DK09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2009.gml')
EE09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2009.gml')
ES09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2009.gml')
FI09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2009.gml')
FR09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2009.gml')
GR09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2009.gml')
HU09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2009.gml')
IE09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2009.gml')
IT09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2009.gml')
LT09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2009.gml')
LV09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2009.gml')
NL09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2009.gml')
NO09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2009.gml')
PL09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2009.gml')
PT09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2009.gml')
RO09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2009.gml')
SE09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2009.gml')
SI09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2009.gml')
SK09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2009.gml')
UK09=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2009.gml')

# %%
Clusters2009 = np.array((round(bipartite.robins_alexander_clustering(AT09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(BE09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(BG09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(CY09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(CZ09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(DE09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(DK09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(EE09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(ES09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(FI09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(FR09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(GR09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(HU09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(IE09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(IT09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(LT09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(LV09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(NL09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(NO09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(PL09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(PT09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(RO09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(SE09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(SI09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(SK09), 3)))
Clusters2009 = np.append(Clusters2009,(round(bipartite.robins_alexander_clustering(UK09), 3)))

df_Clusters2009=pd.DataFrame(Clusters2009, columns=['Y2009'])
df_Clusters2009.to_excel('Cluster2009.xlsx')

# %%
AT10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2010.gml')
BE10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2010.gml')
BG10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2010.gml')
CY10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2010.gml')
CZ10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2010.gml')
DE10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2010.gml')
DK10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2010.gml')
EE10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2010.gml')
ES10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2010.gml')
FI10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2010.gml')
FR10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2010.gml')
GR10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2010.gml')
HU10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2010.gml')
IE10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2010.gml')
IT10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2010.gml')
LT10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2010.gml')
LV10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2010.gml')
NL10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2010.gml')
NO10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2010.gml')
PL10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2010.gml')
PT10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2010.gml')
RO10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2010.gml')
SE10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2010.gml')
SI10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2010.gml')
SK10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2010.gml')
UK10=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2010.gml')

# %%
Clusters2010 = np.array((round(bipartite.robins_alexander_clustering(AT10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(BE10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(BG10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(CY10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(CZ10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(DE10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(DK10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(EE10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(ES10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(FI10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(FR10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(GR10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(HU10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(IE10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(IT10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(LT10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(LV10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(NL10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(NO10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(PL10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(PT10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(RO10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(SE10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(SI10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(SK10), 3)))
Clusters2010 = np.append(Clusters2010,(round(bipartite.robins_alexander_clustering(UK10), 3)))

df_Clusters2010=pd.DataFrame(Clusters2010, columns=['Y2010'])
df_Clusters2010.to_excel('Cluster2010.xlsx')

# %%
AT12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2011.gml')
BE11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2011.gml')
BG11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2011.gml')
CY11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2011.gml')
CZ11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2011.gml')
DE11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2011.gml')
DK11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2011.gml')
EE11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2011.gml')
ES11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2011.gml')
FI11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2011.gml')
FR11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2011.gml')
GR11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2011.gml')
HU11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2011.gml')
IE11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2011.gml')
IT11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2011.gml')
LT11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2011.gml')
LV11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2011.gml')
NL11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2011.gml')
NO11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2011.gml')
PL11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2011.gml')
PT11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2011.gml')
RO11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2011.gml')
SE11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2011.gml')
SI11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2011.gml')
SK11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2011.gml')
UK11=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2011.gml')

# %%
Clusters2011 = np.array((round(bipartite.robins_alexander_clustering(AT11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(BE11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(BG11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(CY11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(CZ11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(DE11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(DK11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(EE11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(ES11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(FI11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(FR11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(GR11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(HU11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(IE11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(IT11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(LT11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(LV11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(NL11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(NO11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(PL11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(PT11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(RO11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(SE11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(SI11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(SK11), 3)))
Clusters2011 = np.append(Clusters2011,(round(bipartite.robins_alexander_clustering(UK11), 3)))

df_Clusters2011=pd.DataFrame(Clusters2011, columns=['Y2011'])
df_Clusters2011.to_excel('Cluster2011.xlsx')

# %%
AT12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2012.gml')
BE12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2012.gml')
BG12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2012.gml')
CY12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2012.gml')
CZ12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2012.gml')
DE12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2012.gml')
DK12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2012.gml')
EE12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2012.gml')
ES12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2012.gml')
FI12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2012.gml')
FR12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2012.gml')
GR12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2012.gml')
HU12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2012.gml')
IE12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2012.gml')
IT12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2012.gml')
LT12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2012.gml')
LV12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2012.gml')
NL12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2012.gml')
NO12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2012.gml')
PL12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2012.gml')
PT12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2012.gml')
RO12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2012.gml')
SE12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2012.gml')
SI12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2012.gml')
SK12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2012.gml')
UK12=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2012.gml')

# %%
Clusters2012 = np.array((round(bipartite.robins_alexander_clustering(AT12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(BE12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(BG12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(CY12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(CZ12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(DE12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(DK12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(EE12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(ES12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(FI12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(FR12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(GR12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(HU12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(IE12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(IT12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(LT12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(LV12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(NL12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(NO12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(PL12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(PT12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(RO12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(SE12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(SI12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(SK12), 3)))
Clusters2012 = np.append(Clusters2012,(round(bipartite.robins_alexander_clustering(UK12), 3)))

df_Clusters2012=pd.DataFrame(Clusters2012, columns=['Y2012'])
df_Clusters2012.to_excel('Cluster2012.xlsx')

# %%
AT13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2013.gml')
BE13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2013.gml')
BG13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2013.gml')
CY13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2013.gml')
CZ13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2013.gml')
DE13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2013.gml')
DK13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2013.gml')
EE13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2013.gml')
ES13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2013.gml')
FI13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2013.gml')
FR13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2013.gml')
GR13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2013.gml')
HU13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2013.gml')
IE13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2013.gml')
IT13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2013.gml')
LT13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2013.gml')
LV13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2013.gml')
NL13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2013.gml')
NO13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2013.gml')
PL13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2013.gml')
PT13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2013.gml')
RO13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2013.gml')
SE13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2013.gml')
SI13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2013.gml')
SK13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2013.gml')
UK13=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2013.gml')

# %%
Clusters2013 = np.array((round(bipartite.robins_alexander_clustering(AT13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(BE13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(BG13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(CY13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(CZ13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(DE13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(DK13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(EE13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(ES13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(FI13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(FR13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(GR13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(HU13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(IE13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(IT13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(LT13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(LV13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(NL13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(NO13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(PL13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(PT13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(RO13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(SE13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(SI13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(SK13), 3)))
Clusters2013 = np.append(Clusters2013,(round(bipartite.robins_alexander_clustering(UK13), 3)))

df_Clusters2013=pd.DataFrame(Clusters2013, columns=['Y2013'])
df_Clusters2013.to_excel('Cluster2013.xlsx')

# %%
AT14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2014.gml')
BE14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2014.gml')
BG14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2014.gml')
CY14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2014.gml')
CZ14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2014.gml')
DE14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2014.gml')
DK14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2014.gml')
EE14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2014.gml')
ES14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2014.gml')
FI14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2014.gml')
FR14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2014.gml')
GR14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2014.gml')
HU14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2014.gml')
IE14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2014.gml')
IT14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2014.gml')
LT14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2014.gml')
LV14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2014.gml')
NL14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2014.gml')
NO14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2014.gml')
PL14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2014.gml')
PT14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2014.gml')
RO14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2014.gml')
SE14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2014.gml')
SI14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2014.gml')
SK14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2014.gml')
UK14=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2014.gml')

# %%
Clusters2014 = np.array((round(bipartite.robins_alexander_clustering(AT14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(BE14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(BG14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(CY14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(CZ14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(DE14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(DK14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(EE14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(ES14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(FI14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(FR14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(GR14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(HU14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(IE14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(IT14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(LT14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(LV14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(NL14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(NO14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(PL14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(PT14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(RO14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(SE14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(SI14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(SK14), 3)))
Clusters2014 = np.append(Clusters2014,(round(bipartite.robins_alexander_clustering(UK14), 3)))

df_Clusters2014=pd.DataFrame(Clusters2014, columns=['Y2014'])
df_Clusters2014.to_excel('Cluster2014.xlsx')

# %%
AT15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2015.gml')
BE15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2015.gml')
BG15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2015.gml')
CY15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2015.gml')
CZ15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2015.gml')
DE15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2015.gml')
DK15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2015.gml')
EE15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2015.gml')
ES15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2015.gml')
FI15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2015.gml')
FR15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2015.gml')
GR15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2015.gml')
HU15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2015.gml')
IE15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2015.gml')
IT15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2015.gml')
LT15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2015.gml')
LV15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2015.gml')
NL15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2015.gml')
NO15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2015.gml')
PL15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2015.gml')
PT15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2015.gml')
RO15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2015.gml')
SE15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2015.gml')
SI15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2015.gml')
SK15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2015.gml')
UK15=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2015.gml')

# %%
Clusters2015 = np.array((round(bipartite.robins_alexander_clustering(AT15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(BE15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(BG15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(CY15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(CZ15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(DE15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(DK15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(EE15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(ES15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(FI15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(FR15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(GR15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(HU15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(IE15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(IT15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(LT15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(LV15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(NL15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(NO15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(PL15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(PT15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(RO15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(SE15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(SI15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(SK15), 3)))
Clusters2015 = np.append(Clusters2015,(round(bipartite.robins_alexander_clustering(UK15), 3)))

df_Clusters2015=pd.DataFrame(Clusters2015, columns=['Y2015'])
df_Clusters2015.to_excel('Cluster2015.xlsx')

# %%
AT16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/AT_2016.gml')
BE16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BE_2016.gml')
BG16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/BG_2016.gml')
CY16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CY_2016.gml')
CZ16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/CZ_2016.gml')
DE16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DE_2016.gml')
DK16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/DK_2016.gml')
EE16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/EE_2016.gml')
ES16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/ES_2016.gml')
FI16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FI_2016.gml')
FR16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/FR_2016.gml')
GR16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/GR_2016.gml')
HU16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/HU_2016.gml')
IE16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IE_2016.gml')
IT16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/IT_2016.gml')
LT16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LT_2016.gml')
LV16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/LV_2016.gml')
NL16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NL_2016.gml')
NO16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/NO_2016.gml')
PL16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PL_2016.gml')
PT16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/PT_2016.gml')
RO16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/RO_2016.gml')
SE16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SE_2016.gml')
SI16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SI_2016.gml')
SK16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/SK_2016.gml')
UK16=nx.read_gml('C:/Users/USER/Documents/universidad/Trabajo de grado/country_year_networks/UK_2016.gml')

# %%
Clusters2016 = np.array((round(bipartite.robins_alexander_clustering(AT16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(BE16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(BG16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(CY16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(CZ16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(DE16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(DK16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(EE16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(ES16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(FI16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(FR16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(GR16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(HU16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(IE16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(IT16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(LT16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(LV16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(NL16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(NO16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(PL16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(PT16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(RO16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(SE16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(SI16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(SK16), 3)))
Clusters2016 = np.append(Clusters2016,(round(bipartite.robins_alexander_clustering(UK16), 3)))

df_Clusters2016=pd.DataFrame(Clusters2016, columns=['Y2016'])
df_Clusters2016.to_excel('Cluster2016.xlsx')
